# %% [markdown]
# ## 1. Manipulating Text Files

# %% [markdown]
# ### 1.1 Count Lines in a File:
#
# Write a Bash script that counts the number of lines in a text file named "document.txt".

# %% [markdown]
# ### 1.2 Count Words in a File:
#
# Write a Bash script that counts the number of words in a text file named "document.txt".

# %% [markdown]
# ### 1.3 Count Characters in a File:
#
# Write a Bash script that counts the number of characters in a text file named "document.txt".

# %% [markdown]
# ### 1.4 Search for a String:
#
# Write a Bash script that searches for a specific string (provided as an argument) in a text file named "document.txt".

# %% [markdown]
# ### 1.5 Write a Bash script that replaces all occurrences of a word with another word in a text file named "output.txt".

# %% [markdown]
# ### 1.6 Sort Lines in a File:
#
# Write a Bash script that sorts the lines in a text file named "out.txt" alphabetically.

# %% [markdown]
# ### 1.7 Write a Bash script that extracts text between specified HTML tags from a file named "jsbin.html".
#
# Content of HTML File:
# ```html
# <html>
# <head>
#   <meta charset="utf-8">
#   <meta name="viewport" content="width=device-width">
#   <title>JS Bin</title>
# </head>
#
# <body>
# <h1>JS Bin Editor</h1>
# </body>
# </html>
# ```

# %% [markdown]
# ### 1.8 Concatenate Files:
#
# Write a Bash script that concatenates the contents of two text files named "file1.txt" and "file2.txt" into a new file named "file.txt".

# %% [markdown]
# ### 1.9 Remove Empty Lines:
#
# Write a Bash script that removes empty lines from a text file named "document.txt".

# %% [markdown]
# ### 1.10 Convert Text to Uppercase:
#
# Write a Bash script that converts all text in a file named "file1.txt" to uppercase.

# %% [markdown]
# ## 2. Searching for Patterns using GREP

# %% [markdown]
# ### 2.1 Search for a specific word in a text file:

# %% [markdown]
# ### 2.2 Search for a word in multiple files:

# %% [markdown]
# ### 2.3 Search for a word ignoring case:

# %% [markdown]
# ### 2.4 Search for a word recursively in all files in a directory:

# %% [markdown]
# ### 2.5 Search for a word and display line numbers:

# %% [markdown]
# ### 2.6 Search for lines that do not contain a word:

# %% [markdown]
# ### 2.7 Search for lines starting with a specific pattern:

# %% [markdown]
# ### 2.8 Search for lines ending with a specific pattern:

# %% [markdown]
# ### 2.9 Search for lines containing any of multiple patterns:

# %% [markdown]
# ### 2.10 Search for lines matching a pattern and count occurrences:

# %% [markdown]
# ### 2.11 Search for lines containing a word with a specified number of characters:

# %% [markdown]
# ### 2.12 Search for lines containing a word starting with a specific letter:

# %% [markdown]
# ### 2.13 Search for lines containing a word with a specific number of occurrences of a character:

# %% [markdown]
# ### 2.14 Search for lines containing a word with a specific range of occurrences of a character:

# %% [markdown]
# ### 2.15 Search for lines containing a word with a specific pattern using regular expressions:

# %% [markdown]
# ## 3. Text Substitution and Manipulation

# %% [markdown]
# ### 3.1 Replace a word:
#
# Write a Bash script that replaces all occurrences of a word with another word in a text file named "temp.txt".

# %% [markdown]
# ### 3.2 Uppercase conversion:
#
# Write a Bash script that converts all text in a file named "temp.txt" to uppercase.

# %% [markdown]
# ### 3.3 Lowercase conversion:
#
# Write a Bash script that converts all text in a file named "temp.txt" to lowercase.

# %% [markdown]
# ### 3.4 Reverse lines:
#
# Write a Bash script that reverses the lines in a text file named "temp.txt".

# %% [markdown]
# ### 3.5 Reverse characters:
#
# Write a Bash script that reverses the characters in each line of a text file named "temp.txt".

# %% [markdown]
# ### 3.6 Remove empty lines:
#
# Write a Bash script that removes empty lines from a text file named "file.txt".

# %% [markdown]
# ### 3.7 Trim leading and trailing whitespace:
#
# Write a Bash script that trims leading and trailing whitespace from each line in a text file named "data.txt".

# %% [markdown]
# ### 3.8 Insert text at beginning of each line:
#
# Write a Bash script that inserts text at the beginning of each line in a text file named "file.txt".

# %% [markdown]
# ### 3.9 Insert text at the end of each line:
#
# Write a Bash script that inserts text at the end of each line in a text file named "file.txt".

# %% [markdown]
# ## 4. Counting Words, Lines and Characters

# %% [markdown]
# ### 4.1 Write a Bash script to count the number of lines in a text file named "document.txt".

# %% [markdown]
# ### 4.2 Write a Bash script to count the number of words in a text file named "data.txt".

# %% [markdown]
# ### 4.3 Write a Bash script to count the number of characters in a text file named "document.txt".

# %% [markdown]
# ### 4.4 Write a Bash script to count the number of lines in a text file excluding empty lines.

# %% [markdown]
# ### 4.5 Write a Bash script to count the number of words in a text file excluding specific words (e.g., "the", "and").

# %% [markdown]
# ### 4.6 Write a Bash script to count the number of characters in a text file excluding spaces and special characters.

# %% [markdown]
# ### 4.7 Write a Bash script to count the number of lines containing a specific word (e.g., "shell") in a text file.

# %% [markdown]
# ### 4.8 Write a Bash script to count the number of occurrences of a specific word (e.g., "is") in a text file.

# %% [markdown]
# ### 4.9 Write a Bash script to count the number of characters in the longest line of a text file.

# %% [markdown]
# ### 4.10 Write a Bash script to count the number of unique words in a text file.

# %% [markdown]
# ## 5. Sorting and Filtering Text

# %% [markdown]
# ### 5.1 Sort lines in alphabetical order:
#
# Write a Bash script that sorts the lines of a text file named "temp.txt" in alphabetical order and saves the result in a new file named "sorted_data.txt".

# %% [markdown]
# ### 5.2 Sort lines in reverse alphabetical order:
#
# Write a Bash script that sorts the lines of a text file named "temp.txt" in reverse alphabetical order and saves the result in a new file named "reverse_sorted_data.txt".

# %% [markdown]
# ### 5.3 Sort lines by line length:
#
# Write a Bash script that sorts the lines of a text file named "temp.txt" by their length (number of characters) and saves the result in a new file named "length_sorted_data.txt".

# %% [markdown]
# ### 5.4 Sort Lines Numerically:
#
# Write a Bash script that sorts the lines of a text file named "temp.txt" numerically and saves the result in a new file named "sorted_numbers.txt".

# %% [markdown]
# ### 5.5 Filter Lines Containing a Specific Word:
#
# Write a Bash script that filters the lines of a text file named "temp.txt" to include only those containing a specific word (e.g., "keyword") and saves the result in a new file named "filtered_data.txt".

# %% [markdown]
# ### 5.6 Filter Lines Not Containing a Specific Word:
#
# Write a Bash script that filters the lines of a text file named "temp.txt" to exclude those containing a specific word (e.g., "exclude_word") and saves the result in a new file named "filtered_data.txt".

# %% [markdown]
# ### 5.7 Filter Lines by Line Length:
#
# Write a Bash script that filters the lines of a text file named "temp.txt" based on their length (e.g., lines with more than 50 characters) and saves the result in a new file named "filtered_data.txt".

# %% [markdown]
# ### 5.8 Filter Lines by Line Prefix:
#
# Write a Bash script that filters the lines of a text file named "temp.txt" to include only those starting with a specific prefix (e.g., "prefix_") and saves the result in a new file named "filtered_data.txt".

# %% [markdown]
# ### 5.9 Remove Duplicate Lines:
#
# Write a Bash script that removes duplicate lines from a text file named "data.txt" and saves the result in a new file named "unique_data.txt".
